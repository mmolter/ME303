# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from scipy.integrate import odeint
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
def pendulum(y, t, c, g, Io):
    theta, omega = y
    
    dydt = [omega, (- g * np.sin(theta) - c * omega) / Io]
    
    return dydt

# %%
c = 0
g = 9.81
Io = 2

# %%
yo = [160 * np.pi / 180.0, 0 * np.pi / 180.]

# %%
t = np.linspace(0, 25, 1000)

# %%
sol = odeint(pendulum, yo, t, args=(b,g,Io))

# %%
plt.plot(t, sol[:, 0] * 180 / np.pi, 'b', label=r'$\theta(t)$')
plt.plot(t, sol[:, 1] * 180 / np.pi, 'lightblue', label=r'$\omega(t)$')


plt.axhline(0, c='k', linewidth=1, linestyle='--', zorder=0)

plt.xlabel('Time (s)')
plt.ylabel('Amplitude (deg)')

plt.legend()

plt.show()
